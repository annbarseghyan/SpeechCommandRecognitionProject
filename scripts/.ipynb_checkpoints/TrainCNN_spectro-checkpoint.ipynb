# %%
import os

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

import sys
import os
sys.path.append(os.path.abspath(".."))

from ModelComponents.spectroArchitectures import CNN_spectro
from ModelComponents.dataset_spectro import FolderAudioDataset
from ModelComponents.training import train
from ModelComponents.utils import plot_training_curves

# %%
datasets_path = "../../examples"
preprocessed_path = os.path.join(datasets_path,"preprocessed/")
checkpoint_path = '../../models/MLPv0.pth'
training_plot_save_path = '../../results/MLPPerformance.png'

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_CNN = CNN_spectro().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_CNN.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

num_epochs = 10
batch_size = 4
noise_prob_train = 0.7
noise_prob_test = 0

# %%
data_train = FolderAudioDataset(os.path.join(preprocessed_path,"train"), os.path.join(datasets_path,"bruits"), noise_prob=noise_prob_train)
train_loader = DataLoader(data_train, batch_size=batch_size, shuffle=True)


data_test = FolderAudioDataset(os.path.join(preprocessed_path,"test"), os.path.join(datasets_path,"bruits"), noise_prob=noise_prob_test)
test_loader = DataLoader(data_test, batch_size=batch_size, shuffle=True)

# %%
train_loss_list, train_acc_list, test_loss_list, test_acc_list = train(model_CNN, train_loader, test_loader, criterion, optimizer, checkpoint_path, device, num_epochs, scheduler)
# Out:
# Epoch [1/10]
# Train Loss: 1596.5322, Train Acc: 27.78%
# Test Loss: 2.5618, Test Acc: 16.67%
#
# Best model saved with accuracy: 16.67%
# Epoch [2/10]
# Train Loss: 18.9302, Train Acc: 11.11%
# Test Loss: 1.7965, Test Acc: 16.67%
#
# Epoch [3/10]
# Train Loss: 2.2199, Train Acc: 16.67%
# Test Loss: 1.7937, Test Acc: 16.67%
#
# Epoch [4/10]
# Train Loss: 1.7946, Train Acc: 16.67%
# Test Loss: 1.7938, Test Acc: 16.67%
#
# Epoch [5/10]
# Train Loss: 1.7936, Train Acc: 16.67%
# Test Loss: 1.7933, Test Acc: 16.67%
#
# Epoch [6/10]
# Train Loss: 1.7927, Train Acc: 16.67%
# Test Loss: 1.7960, Test Acc: 16.67%
#
# Epoch [7/10]
# Train Loss: 1.7948, Train Acc: 16.67%
# Test Loss: 1.7953, Test Acc: 16.67%
#
# Epoch [8/10]
# Train Loss: 1.7785, Train Acc: 16.67%
# Test Loss: 1.7949, Test Acc: 16.67%
#
# Epoch [9/10]
# Train Loss: 1.7908, Train Acc: 16.67%
# Test Loss: 1.7884, Test Acc: 16.67%
#
# Epoch [10/10]
# Train Loss: 1.7858, Train Acc: 16.67%
# Test Loss: 1.7971, Test Acc: 16.67%

# %%
plot_training_curves(train_loss_list, test_loss_list, train_acc_list, test_acc_list, num_epochs, training_plot_save_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plot_training_curves(train_loss_list, test_loss_list, train_acc_list, test_acc_list, num_epochs, training_plot_save_path)
#
# File ~/document/SpeechCommandRecognitionProject/ModelComponents/utils.py:28, in plot_training_curves(train_loss_list, test_loss_list, train_acc_list, test_acc_list, num_epochs, save_path)
#      25 plt.tight_layout()
#      27 if save_path:
# ---> 28     plt.savefig(save_path, dpi=300)
#      29     print(f"Plot saved to {save_path}")
#      30 else:
#
# File ~/miniforge3/envs/decode_env/lib/python3.8/site-packages/matplotlib/pyplot.py:859, in savefig(*args, **kwargs)
#     856 @_copy_docstring_and_deprecators(Figure.savefig)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# File ~/miniforge3/envs/decode_env/lib/python3.8/site-packages/matplotlib/figure.py:2311, in Figure.savefig(self, fname, transparent, **kwargs)
#    2308         patch.set_facecolor('none')
#    2309         patch.set_edgecolor('none')
# -> 2311 self.canvas.print_figure(fname, **kwargs)
#    2313 if transparent:
#    2314     for ax, cc in zip(self.axes, original_axes_colors):
#
# File ~/miniforge3/envs/decode_env/lib/python3.8/site-packages/matplotlib/backend_bases.py:2210, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2207     _bbox_inches_restore = None
#    2209 try:
# -> 2210     result = print_method(
#    2211         filename,
#    2212         dpi=dpi,
#    2213         facecolor=facecolor,
#    2214         edgecolor=edgecolor,
#    2215         orientation=orientation,
#    2216         bbox_inches_restore=_bbox_inches_restore,
#    2217         **kwargs)
#    2218 finally:
#    2219     if bbox_inches and restore_bbox:
#
# File ~/miniforge3/envs/decode_env/lib/python3.8/site-packages/matplotlib/backend_bases.py:1639, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1631     cbook.warn_deprecated(
#    1632         '3.3', name=name,
#    1633         message='%(name)s() got unexpected keyword argument "'
#    1634                 + arg + '" which is no longer supported as of '
#    1635                 '%(since)s and will become an error '
#    1636                 '%(removal)s')
#    1637     kwargs.pop(arg)
# -> 1639 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/decode_env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:510, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     463 """
#     464 Write the figure to a PNG file.
#     465
#    (...)
#     507     *metadata*, including the default 'Software' key.
#     508 """
#     509 FigureCanvasAgg.draw(self)
# --> 510 mpl.image.imsave(
#     511     filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/miniforge3/envs/decode_env/lib/python3.8/site-packages/matplotlib/image.py:1605, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1603 pil_kwargs.setdefault("format", format)
#    1604 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1605 image.save(fname, **pil_kwargs)
#
# File ~/miniforge3/envs/decode_env/lib/python3.8/site-packages/PIL/Image.py:2317, in Image.save(self, fp, format, **params)
#    2315         fp = builtins.open(filename, "r+b")
#    2316     else:
# -> 2317         fp = builtins.open(filename, "w+b")
#    2319 try:
#    2320     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../results/MLPPerformance.png'
