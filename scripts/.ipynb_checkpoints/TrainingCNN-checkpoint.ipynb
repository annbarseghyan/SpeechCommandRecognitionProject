# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
import os

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

from ModelComponents.MFCCArchitectures import CNN
from ModelComponents.dataset import FolderAudioDataset
from ModelComponents.training import train
from ModelComponents.utils import plot_training_curves

# %% [markdown]
# ## Define training arguments

# %%
datasets_path = "../../tp_tap_new/datasets"
preprocessed_path = os.path.join(datasets_path,"preprocessed/")

results_path = "../results/CNN_v0" # changer l'emplacement du dossier en fonction du modèle entraîné
checkpoint_path = os.path.join(results_path,"model.pth")
training_plot_save_path = os.path.join(results_path,"Performance.png")


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_CNN = CNN().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_CNN.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

num_epochs = 10
batch_size = 100
noise_prob_train = 0.8
noise_prob_test = 0

# %%
data_train = FolderAudioDataset(os.path.join(preprocessed_path,"train"), os.path.join(datasets_path,"bruits"), noise_prob=noise_prob_train)
train_loader = DataLoader(data_train, batch_size=batch_size, shuffle=True)


data_test = FolderAudioDataset(os.path.join(preprocessed_path,"test"), os.path.join(datasets_path,"bruits"), noise_prob=noise_prob_test)
test_loader = DataLoader(data_test, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Training

# %%
train_loss_list, train_acc_list, test_loss_list, test_acc_list = train(model_CNN, train_loader, test_loader, criterion, optimizer, checkpoint_path, device, num_epochs, scheduler)
# Out:
# Epoch [1/10]
# Train Loss: 0.6003, Train Acc: 84.94%
# Test Loss: 0.5146, Test Acc: 86.26%
#
# Best model saved with accuracy: 86.26%
# Epoch [2/10]
# Train Loss: 0.4974, Train Acc: 86.70%
# Test Loss: 0.6478, Test Acc: 84.68%
#
# Epoch [3/10]
# Train Loss: 0.4735, Train Acc: 87.02%
# Test Loss: 0.4556, Test Acc: 87.06%
#
# Best model saved with accuracy: 87.06%
# Epoch [4/10]
# Train Loss: 0.4580, Train Acc: 87.19%
# Test Loss: 0.4720, Test Acc: 86.26%
#
# Epoch [5/10]
# Train Loss: 0.4493, Train Acc: 87.44%
# Test Loss: 0.4631, Test Acc: 86.82%
#
# Epoch [6/10]
# Train Loss: 0.3984, Train Acc: 88.41%
# Test Loss: 0.4025, Test Acc: 88.14%
#
# Best model saved with accuracy: 88.14%
# Epoch [7/10]
# Train Loss: 0.3909, Train Acc: 88.63%
# Test Loss: 0.4074, Test Acc: 88.06%
#
# Epoch [8/10]
# Train Loss: 0.3842, Train Acc: 88.74%
# Test Loss: 0.3977, Test Acc: 88.09%
#
# Epoch [9/10]
# Train Loss: 0.3800, Train Acc: 88.88%
# Test Loss: 0.4033, Test Acc: 87.93%
#
# Epoch [10/10]
# Train Loss: 0.3783, Train Acc: 88.96%
# Test Loss: 0.3968, Test Acc: 88.53%
#
# Best model saved with accuracy: 88.53%

# %%
plot_training_curves(train_loss_list, test_loss_list, train_acc_list, test_acc_list, num_epochs, training_plot_save_path)
# Out:
# Plot saved to ../../results/CNNPerformance.png
