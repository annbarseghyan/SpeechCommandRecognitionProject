# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
import os

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

from ModelComponents.MFCCArchitectures import VanillaMLP
from ModelComponents.dataset import FolderAudioDataset
from ModelComponents.training import train
from ModelComponents.utils import plot_training_curves

# %% [markdown]
# ## Define training arguments

# %%
datasets_path = "../../tp_tap_new/datasets"
preprocessed_path = os.path.join(datasets_path,"preprocessed/")

results_path = "../results/Vanilla_v0" # changer l'emplacement du dossier en fonction du modèle entraîné
checkpoint_path = os.path.join(results_path,"model.pth")
training_plot_save_path = os.path.join(results_path,"Performance.png")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_VanillaMLP = VanillaMLP().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_VanillaMLP.parameters(), lr=0.001)

num_epochs = 10
batch_size = 100
noise_prob_train = 0.8
noise_prob_test = 0

# %%
device
# Out:
# device(type='cuda')

# %%
data_train = FolderAudioDataset(os.path.join(preprocessed_path,"train"), os.path.join(datasets_path,"bruits"), noise_prob=noise_prob_train)
train_loader = DataLoader(data_train, batch_size=batch_size, shuffle=True)


data_test = FolderAudioDataset(os.path.join(preprocessed_path,"test"), os.path.join(datasets_path,"bruits"), noise_prob=noise_prob_test)
test_loader = DataLoader(data_test, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Training

# %%
train_loss_list, train_acc_list, test_loss_list, test_acc_list = train(model_VanillaMLP, train_loader, test_loader, criterion, optimizer, checkpoint_path, device, num_epochs, cnn=False)
# Out:
# Epoch [1/10]
# Train Loss: 1.2168, Train Acc: 82.86%
# Test Loss: 0.5709, Test Acc: 84.41%
#
# Best model saved with accuracy: 84.41%
# Epoch [2/10]
# Train Loss: 0.5572, Train Acc: 84.24%
# Test Loss: 0.6631, Test Acc: 84.56%
#
# Best model saved with accuracy: 84.56%
# Epoch [3/10]
# Train Loss: 0.4894, Train Acc: 86.21%
# Test Loss: 0.5040, Test Acc: 84.15%
#
# Epoch [4/10]
# Train Loss: 0.4658, Train Acc: 86.86%
# Test Loss: 0.4371, Test Acc: 87.65%
#
# Best model saved with accuracy: 87.65%
# Epoch [5/10]
# Train Loss: 0.4631, Train Acc: 87.01%
# Test Loss: 0.4726, Test Acc: 87.45%
#
# Epoch [6/10]
# Train Loss: 0.4524, Train Acc: 87.09%
# Test Loss: 0.4533, Test Acc: 86.83%
#
# Epoch [7/10]
# Train Loss: 0.4548, Train Acc: 87.11%
# Test Loss: 0.4560, Test Acc: 87.72%
#
# Best model saved with accuracy: 87.72%
# Epoch [8/10]
# Train Loss: 0.4453, Train Acc: 87.25%
# Test Loss: 0.4412, Test Acc: 86.56%
#
# Epoch [9/10]
# Train Loss: 0.4493, Train Acc: 87.20%
# Test Loss: 0.4429, Test Acc: 86.89%
#
# Epoch [10/10]
# Train Loss: 0.4508, Train Acc: 87.18%
# Test Loss: 0.4794, Test Acc: 86.42%

# %%
plot_training_curves(train_loss_list, test_loss_list, train_acc_list, test_acc_list, num_epochs, training_plot_save_path)
# Out:
# Plot saved to ../../results/model_VanillaMLPPerformance.png
